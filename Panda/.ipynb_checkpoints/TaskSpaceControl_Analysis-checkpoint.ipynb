# %% [markdown]
# # Task-Space Control of a 6 dof manipulator

# %% [markdown]
# ## Imort all the modules needed for the simulation

# %%
from pickle import GLOBAL
import pinocchio as pin
import numpy as np
import sys
import os
from os.path import dirname, join, abspath
from pinocchio.visualize import MeshcatVisualizer
import time
import math
import meshcat
import matplotlib.pyplot as plt
from numpy.linalg import norm, solve
from scipy.spatial.transform import Rotation
import meshcat.transformations as tf
import meshcat.geometry as g
from meshcat.animation import Animation
from numpy.linalg import inv,pinv,eig,norm,svd,det
from random import randint
from matplotlib.animation import FuncAnimation, PillowWriter,FFMpegWriter
plt.rcParams['text.usetex'] = True
# %matplotlib inline
# %matplotlib widget

# %% [markdown]
# ## Meshcat functions

# %%
def meshcat_material(r, g, b, a):
    import meshcat

    material = meshcat.geometry.MeshPhongMaterial()
    material.color = int(r * 255) * 256 ** 2 + int(g * 255) * 256 + int(b * 255)
    material.opacity = a
    return material

# %% [markdown]
# ## Bring the URDF model of the robot

# %%
pinocchio_model_dir = '/home/unknown/Documents/PostDoc/Pinocchio_examples/Panda/Panda_description' 
mesh_dir = '/home/unknown/Documents/PostDoc/Pinocchio_examples/Panda/Panda_description/meshes' 
urdf_model_path =pinocchio_model_dir + '/urdf/panda_simple.urdf'
model, collision_model, visual_model = pin.buildModelsFromUrdf(urdf_model_path, mesh_dir)
# Choose of the visualizer
viz = MeshcatVisualizer(model, collision_model, visual_model)
# gravity_ = pin.Motion.Zero()#pin.Motion(np.array([0, 0, 0],[0, 0, 0]))
# model.gravity  = gravity_

# %% [markdown]
# ## Identify the frame and joint IDs

# %%
frameIndex = model.getFrameId('panda_link8')
jointIndex = model.frames[frameIndex].parent

# %% [markdown]
# ## Initialize the viewer

# %%
try:
    viz.initViewer()
except ImportError as err:
    print("Error while initializing the viewer. It seems you should install gepetto-viewer")
    print(err)
    sys.exit(0)

try:
    viz.loadViewerModel("pinocchio")
except AttributeError as err:
    print("Error while loading the viewer model. It seems you should start gepetto-viewer")
    print(err)
    sys.exit(0)
viz.viewer['world'].set_transform(np.array(pin.XYZQUATToSE3([0, 0, 0, 0, 0, 1, 0])))
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7004/static/

# %%
# Create data required by the algorithms
data = model.createData()
q =np.array([0,-0.785398163397, 0, -2.35619449019, 0,1.57079632679,0.785398163397]) # Home position
viz.display(q)
isinstance(viz, pin.visualize.MeshcatVisualizer) and viz.viewer.jupyter_cell()
# Out:
#             <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
#             <iframe src="http://127.0.0.1:7004/static/" style="width: 100%; height: 100%; border: none"></iframe>
#             </div>

# %% [markdown]
# ## Manipulator dynamic model

# %% [markdown]
# \begin{equation}
# \mathbf{
# M(q)\ddot{q} + C(q,\dot{q})\dot{q} + g(q) = \tau }
# \end{equation}

# %% [markdown]
# ### The closed loop control law $\tau$ can be written

# %% [markdown]
# \begin{equation}
# \mathbf{
# {\tau} = M(q)u +  g(q) + C(q,\dot{q})}
# \end{equation}
# where
# \begin{equation}
# \mathbf{
# u = J^{-1}(q)(\ddot{x}_d+ K_d \dot{\tilde{x}} + K_p {\tilde{x}} - \dot{J}\dot{q})};  ~~~~~~ \tilde{x}= x_d - x
# \end{equation}

# %% [markdown]
# ## Simulation function

# %%
def run_robot():

    def df_dq(model,func,q,h=1e-9):
        dq = pin.utils.zero(model.nv)
        f0 = func(q)
        AM_i = pin.utils.zero([7,3,3])
        for iq in range(model.nv):
            dq[iq] = h
            res2 = (func(pin.integrate(model,q,dq)) - f0)/h
            AM_i[iq,:,:] = np.array([ [res2[0],res2[3],res2[4]], [res2[3],res2[1],res2[5]], [res2[4],res2[5],res2[2]] ])
            dq[iq] = 0
        return AM_i
    
    def calc_jac3(q):
        """ Compute Jacobian """
        pin.forwardKinematics(model,data,q)
        J = pin.computeJointJacobian(model,data,q,jointIndex)  # in joint frame
        J = -np.dot(pin.Jlog6(iMd.inverse()), J)

        #pin.updateFramePlacements(model,data)
        #pin.computeJointJacobians(model, data, q)
        #J=pin.getFrameJacobian(model,data,frameIndex,pin.LOCAL_WORLD_ALIGNED)
        Jbl = J[:3]
        R = Jbl@Jbl.T
        Rv = np.array([R[0][0],R[1][1], R[2][2], R[0][1], R[0][2], R[1][2]])                      
        return Rv.copy()
    
    # Create data required by the algorithms
    data = model.createData()

    # Sample a random configuration
    q =np.array([0,-0.785398163397, 0, -2.35619449019, 0,1.57079632679,0.785398163397]) # Home position
    qdot = pin.utils.zero(model.nv) # this is the angular velocity 
    a = pin.utils.zero(model.nv)
    qdot_max = np.array([2.61, 2.61, 2.61, 2.61, np.pi,np.pi,np.pi]) #1,2,3,4 = 150 deg/s; 5,6,8 =180 deg/s 

    pin.forwardKinematics(model,data,q)
    pin.updateFramePlacements(model,data) #Computes the placement of all the joints
    #OM_act=data.oMf[model.getFrameId("panda_link8")]
    
    OM_act=data.oMi[jointIndex]
    #print(OM_act.translation)
    kappa = 1
    d_bar = 0.1
    # Control variables
    nuvs = 5
    kvs = np.array([nuvs, nuvs, nuvs, nuvs, nuvs, nuvs])
    Kv = np.diag(kvs)

    luvs = 5
    kps = np.array([luvs, luvs, luvs,luvs, luvs, luvs])
    Kp = np.diag(kps)

    alpha = 20
    t = 0
    dt = 5e-2
    T = 5
    N = math.floor(T/dt)
    
    # for graphs
    t_list = []
    u_list = []    
    q_list = [] #q
    pose_list = []
    pose_des_list = []
    Mdn_list = []
    Md_list = []
    kappa_list = []
    d_list = []
    Dkappa_list = []
    E1_list = []
    E2_list = []
    posdot_list = []
    xo=-0.2; yo =-0.25; zo=0.4 # Position of the obstacle  -0.38478977, -0.5, 0.4
    # This is the desired orientation and pose. The static pose is [-0.38478977 -0.0098      0.38623122]
    oMdes = pin.SE3(OM_act.rotation,np.array([OM_act.translation[0]+0.2, OM_act.translation[1]+0.3, OM_act.translation[2]]))  
    
    viz.viewer['world/ball'].set_object(g.Sphere(0.03),
                                    meshcat_material(*[0.4, 0.5,0.1, 1]))
    viz.viewer['world/ball'].set_transform(tf.translation_matrix([oMdes.translation[0]*-1, 
                                                                  oMdes.translation[1]*-1, oMdes.translation[2]]))
    
    viz.viewer['world/obs'].set_object(g.Sphere(0.03),
                                    meshcat_material(*[1, 0.16, 0.12, 1]))
    viz.viewer['world/obs'].set_transform(tf.translation_matrix([xo*-1, yo*-1, zo]))

    viz.viewer['world/ball0'].set_object(g.Sphere(0.03),
                                    meshcat_material(*[0.1, 0.5, 1, 1]))
    viz.viewer['world/ball0'].set_transform(tf.translation_matrix([OM_act.translation[0]*-1, 
                                                                  OM_act.translation[1]*-1, OM_act.translation[2]]))
           
    for k in range(N):
        t += dt
        tic = time.time()

        pin.forwardKinematics(model,data,q)
        #pin.updateFramePlacements(model,data)
        #OM_act = data.oMf[frameIndex]
        data.oMi[jointIndex]
        iMd = data.oMi[jointIndex].actInv(oMdes)
        err = pin.log(iMd).vector  # in joint frame
        J = pin.computeJointJacobian(model,data,q,jointIndex)  # in joint frame
        J = -np.dot(pin.Jlog6(iMd.inverse()), J)

        #pin.computeJointJacobians(model, data, q) # Compute all the Jacobians for all the joints
        #J=pin.getFrameJacobian(model,data,frameIndex,pin.LOCAL_WORLD_ALIGNED) # in the base frame  
        J_plus =J.T@np.linalg.pinv(J@J.T) 
        dJ = pin.computeJointJacobiansTimeVariation(model,data,q,qdot) # Derivative of the Jacobian
        Jbl = J[:3] # linear part of the Jacobian
        Al = Jbl@Jbl.T 
        Al_inv = inv(Al)      
        Al_det = det(Al)        
        pos = np.array([OM_act.translation[0],OM_act.translation[1],OM_act.translation[2]])
        dJ_dqn = df_dq(model,lambda _q: calc_jac3(_q),q)
        
        for i in range(6):
            dJ_dqn[i,:,:] = dJ_dqn[i]*qdot_max[i]
        P_o = np.array([xo,yo,zo])
        d = P_o.T - pos.T 
        #dir_obs = P_o@ d/norm(d)
        #print(dir_obs)
        Zeta = norm(sum(dJ_dqn)@Al_inv)*abs(kappa)
        
        if (norm(d) <= d_bar):
            Dkappa =  Zeta*np.tanh(alpha*d.T@(Jbl@qdot))
        else:
            Dkappa = 0

        if (norm(d) <= d_bar):  
            kappa = kappa + Dkappa*dt
        else:
            kappa = 1   
        Md = kappa*Al_inv
        
        if Al_det < 1e-15:  
            Al_det = 0.0                
        if Al_det == 0.0:
            E_1 = math.nan
            E_2 = math.nan
        else:
            E_1 = Zeta
            E_2 = Dkappa

        xdot = J@qdot
        # Compute torque control
        u = -Kp@err - Kv@xdot + dJ@qdot
        a = J_plus@u#solve(J,u)
        tau = pin.rnea(model, data, q, qdot, a)

        # Compute forward dynamics
        qddot = pin.aba(model, data, q, qdot, tau)

        qdot = qdot + qddot * dt 
        q = pin.integrate(model,q,qdot*dt)

        # Show model with a visualizer of your choice
        viz.display(q)
        q_list.append(q)
        pose_list.append(pos)
        pose_des_list.append(oMdes.translation)
        t_list.append(t)
        u_list.append(tau)
        d_list.append(norm(d))
        Mdn_list.append(norm(Md))
        Md_list.append((Md))
        kappa_list.append(kappa)
        Dkappa_list.append(Dkappa)
        E1_list.append(E_1)
        E2_list.append(E_2)
        posdot_list.append(xdot)
        toc = time.time() 
        ellapsed = toc - tic
        dt_sleep = max(0,dt - (ellapsed))
        time.sleep(dt_sleep)

    t_list = np.array(t_list)
    u_list = np.array(u_list)
    q_list = np.array(q_list)
    pose_list = np.array(pose_list)
    pose_des_list = np.array(pose_des_list)
    d_list = np.array(d_list)
    Mdn_list = np.array(Mdn_list)
    Md_list = np.array(Md_list)
    kappa_list = np.array(kappa_list)
    Dkappa_list = np.array(Dkappa_list)
    E1_list = np.array(E1_list)
    E2_list = np.array(E2_list)
    posdot_list = np.array(posdot_list)
    return t_list, u_list, q_list, pose_list, pose_des_list, d_list, Mdn_list, kappa_list, Dkappa_list, E1_list, E2_list, posdot_list, Md_list

# %%
isinstance(viz, pin.visualize.MeshcatVisualizer) and viz.viewer.jupyter_cell()
# Out:
#             <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
#             <iframe src="http://127.0.0.1:7004/static/" style="width: 100%; height: 100%; border: none"></iframe>
#             </div>

# %%
t_list, u_list, q_list, pose_list, pose_des_list, d, Mdn, kappa, Dkappa, E1, E2, posdot, Md = run_robot()

# %%
def animate(i):
    """Plot an ellipsoid"""
    radii = 1.0 / np.sqrt(np.diag(Md[i,:,:])) # I neede only s and not radii
    U, s, rotation = svd(Md[i,:,:])
    u = np.linspace(0.0, 2.0 * np.pi, 50)
    v = np.linspace(0.0, np.pi, 50)
    #print(radii)
#     for i in range(len(radii)):
#         cartesian coordinates that correspond to the spherical angles:
    x = np.outer(np.cos(u), np.sin(v))
    y = radii[1] * np.outer(np.sin(u), np.sin(v))
    z = radii[2] * np.outer(np.ones_like(u), np.cos(v))
    
    x[x>0] *= radii[0] 
    # rotate accordingly
    for i in range(len(x)):
        for j in range(len(x)):
            [x[i,j],y[i,j],z[i,j]] = np.dot([x[i,j],y[i,j],z[i,j]], rotation) 
            
    ax.clear()  # Clears the figure to update the line, point,   
#     # Plot:
    ax.plot_surface(x, y, z,  rstride=5, cstride=5, color='r')

    # plot ellipsoid
    ax.plot_wireframe(x, y, z,  rstride=4, cstride=4, color='b', alpha=0.2)
    ax.set_xlim(-0.4,0.8)
    ax.set_ylim(-0.4,0.8)
    ax.set_zlim(-0.6,0.6)
    #plt.show()

# %%
f = r"/home/unknown/Documents/Posdoc/animation.gif" 

fig, ax = plt.subplots()
ax = fig.add_subplot(111, projection='3d')
anim = FuncAnimation(fig, animate, frames=len(Md), interval=20, repeat=False)
plt.show()

writergif = PillowWriter(fps=30) 
anim.save(f, writer=writergif)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# [0.3823941  0.45854058 0.49420182]
# [0.3823941  0.45854058 0.49420182]
# [0.3822243  0.45640593 0.49223641]
# [0.38191399 0.45270513 0.48882684]
# [0.38145573 0.44790898 0.48436772]
# [0.38082492 0.44247059 0.47921407]
# [0.37999999 0.43682215 0.47370243]
# [0.37898089 0.43134196 0.46814366]
# [0.37780032 0.42632646 0.46280938]
# [0.37652559 0.42197867 0.45792167]
# [0.37525251 0.41841123 0.45364894]
# [0.37409487 0.41565773 0.4501072 ]
# [0.37317264 0.41368772 0.44736526]
# [0.37260133 0.41242232 0.44545218]
# [0.35609367 0.3936321  0.42481277]
# [0.34308307 0.37863057 0.40856792]
# [0.33345738 0.36711247 0.39644576]
# [0.32709451 0.35880398 0.38819707]
# [0.32386146 0.35345401 0.38358859]
# [0.32361012 0.35082248 0.38239241]
# [0.32617332 0.35067034 0.38437669]
# [0.33136366 0.35275449 0.38930081]
# [0.33897575 0.35682807 0.39691565]
# [0.34879101 0.36264448 0.40696752]
# [0.36058355 0.36996291 0.41920359]
# [0.37412561 0.37855334 0.43337679]
# [0.38919205 0.38820018 0.44924927]
# [0.40556363 0.39870432 0.46659441]
# [0.42641609 0.41316549 0.48908207]
# [0.43226589 0.41286203 0.49442244]
# [0.43802962 0.41251484 0.49979814]
# [0.44366239 0.41212699 0.50517214]
# [0.44912767 0.41170107 0.51051078]
# [0.45439682 0.41123953 0.51578402]
# [0.45944852 0.41074495 0.52096555]
# [0.46426803 0.41022015 0.52603282]
# [0.46884635 0.40966818 0.53096697]
# [0.47317941 0.40909226 0.53575266]
# [0.4772673  0.40849578 0.5403779 ]
# [0.48111344 0.4078821  0.54483373]
# [0.48472391 0.40725459 0.54911393]
# [0.4881068  0.40661647 0.55321474]
# [0.49127167 0.40597084 0.55713452]
# [0.49422904 0.40532059 0.56087344]
# [0.49698999 0.4046684  0.56443321]
# [0.49956587 0.40401677 0.56781679]
# [0.50196801 0.40336796 0.57102819]
# [0.50420754 0.40272402 0.5740722 ]
# [0.50629522 0.4020868  0.57695423]
# [0.50824136 0.40145797 0.57968014]
# [0.51005576 0.400839   0.58225611]
# [0.51174764 0.40023119 0.58468849]
# [0.51332567 0.39963568 0.58698375]
# [0.51479792 0.39905346 0.58914834]
# [0.51617191 0.39848535 0.59118867]
# [0.51745462 0.39793206 0.59311103]
# [0.51865252 0.39739417 0.59492155]
# [0.5197716  0.39687213 0.59662621]
# [0.52081739 0.3963663  0.59823074]
# [0.52179499 0.39587692 0.59974069]
# [0.52270914 0.39540416 0.60116133]
# [0.52356421 0.39494808 0.60249774]
# [0.52436423 0.39450868 0.60375473]
# [0.52511294 0.39408589 0.60493688]
# [0.52581381 0.39367957 0.60604854]
# [0.52647002 0.39328954 0.60709382]
# [0.52708456 0.39291556 0.60807661]
# [0.52766018 0.39255735 0.6090006 ]
# [0.52819944 0.39221459 0.60986925]
# [0.52870471 0.39188694 0.61068585]
# [0.5291782  0.39157402 0.61145348]
# [0.52962198 0.39127544 0.61217505]
# [0.53003795 0.39099079 0.6128533 ]
# [0.53042789 0.39071962 0.6134908 ]
# [0.53079348 0.39046152 0.61409   ]
# [0.53113626 0.39021604 0.61465317]
# [0.53145768 0.38998272 0.61518246]
# [0.53175908 0.38976111 0.6156799 ]
# [0.53204174 0.38955078 0.61614738]
# [0.53230684 0.38935126 0.6165867 ]
# [0.53255547 0.38916213 0.61699953]
# [0.53278866 0.38898294 0.61738747]
# [0.53300739 0.38881326 0.61775199]
# [0.53321256 0.38865268 0.6180945 ]
# [0.53340502 0.38850078 0.61841631]
# [0.53358554 0.38835717 0.61871867]
# [0.53375489 0.38822146 0.61900274]
# [0.53391374 0.38809327 0.61926961]
# [0.53406276 0.38797223 0.61952032]
# [0.53420255 0.38785799 0.61975582]
# [0.53433369 0.38775021 0.61997705]
# [0.53445671 0.38764857 0.62018484]
# [0.53457211 0.38755275 0.62038002]
# [0.53468037 0.38746244 0.62056334]
# [0.53478193 0.38737736 0.6207355 ]
# [0.5348772  0.38729723 0.6208972 ]
# [0.53496657 0.38722178 0.62104904]
# [0.53505041 0.38715076 0.62119164]
# [0.53512906 0.38708393 0.62132554]
# [0.53520283 0.38702105 0.62145127]
# [0.53527204 0.38696191 0.62156933]

# %%
#Graph kappa
fig, ax = plt.subplots()
ax = plt.subplot(2, 2, 1)
plt.plot(d, kappa)
ax.set_ylabel(r"$\kappa(t)$", fontsize = 14)
ax.set_xlabel('Time (s)')
plt.grid(True)
fig.tight_layout()

ax = plt.subplot(2, 2, 2)
plt.plot(d, Dkappa)
ax.set_ylabel(r"$\dot{\kappa}(t)$", fontsize = 14)
ax.set_xlabel('Time (s)')
plt.grid(True)
fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_10478/476603297.py:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2, 2, 1)

# %%
fig, ax = plt.subplots()
#ax = plt.subplot(3, 2, 1)
plt.plot(d, Mdn)
ax.set_ylabel(r"$ || \Lambda_d(q) || $", fontsize = 14)
ax.set_xlabel('Time (s)')

plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots()
#ax = plt.subplot(3, 2, 1)
plt.plot(t_list, d)
ax.set_ylabel(r"$ ||d|| $", fontsize = 14)
ax.set_xlabel('Time (s)')
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots()
#ax = plt.subplot(3, 2, 1)
plt.plot(d, E1)
plt.plot(d, E2)
ax.legend((r"$E_1$",r"$E_2$"),loc="upper right")
ax.set_ylabel(r"$ E_1,~~ E_2$", fontsize = 14)
ax.set_xlabel('Time (s)')

plt.grid(True)
plt.show()

# %% [markdown]
# ## Graphs functions ($\tau$, $q$, ($\xi_{ee},\eta_{ee})$)

# %%
def graphs_qs(t_list, q_list):
    fig, ax = plt.subplots()
    plt.plot(t_list, q_list[:, :])
    plt.grid(True)
    ax.set_ylabel(r"$q \ [rad]$", fontsize = 14)
    ax.set_xlim(0, max(t_list))
    ax.set_xlabel(r'\textbf{Time (s)}')
    ax.legend((r"$q_0$",r"$q_1$",r"$q_2$",r"$q_3$",r"$q_4$",r"$q_5$"),loc="upper right")
    fig.tight_layout()
    plt.show()

def graphs_taus(t, tau):
    fig, ax = plt.subplots()
    ax = plt.subplot(3, 2, 1)
    plt.plot(t, tau[:, 0])
    plt.grid(True)
    ax.set_ylabel(r"$\tau_0 \ [-]$", fontsize = 14)
    ax.set_xlim(0, max(t_list))
    ax.set_xlabel(r'\textbf{Time (s)}')
    # ax.legend((r"$q_0$",r"$q_{0d}$"),loc="upper right")
    fig.tight_layout()

    ax = plt.subplot(3, 2, 2)
    plt.plot(t, tau[:, 1])
    plt.grid(True)
    ax.set_ylabel(r"$\tau_1 \ [-]$", fontsize = 14)
    ax.set_xlim(0, max(t_list))
    ax.set_xlabel(r'\textbf{Time (s)}')
    # ax.legend((r"$q_0$",r"$q_{0d}$"),loc="upper right")
    fig.tight_layout()

    ax = plt.subplot(3, 2, 3)
    plt.plot(t, tau[:, 2])
    plt.grid(True)
    ax.set_ylabel(r"$\tau_2 \ [-]$", fontsize = 14)
    ax.set_xlim(0, max(t_list))
    ax.set_xlabel(r'\textbf{Time (s)}')
    # ax.legend((r"$q_0$",r"$q_{0d}$"),loc="upper right")
    fig.tight_layout()

    ax = plt.subplot(3, 2, 4)
    plt.plot(t, tau[:, 3])
    plt.grid(True)
    ax.set_ylabel(r"$\tau_3 \ [-]$", fontsize = 14)
    ax.set_xlim(0, max(t_list))
    ax.set_xlabel(r'\textbf{Time (s)}')
    # ax.legend((r"$q_0$",r"$q_{0d}$"),loc="upper right")
    fig.tight_layout()

    ax = plt.subplot(3, 2, 5)
    plt.plot(t, tau[:, 4])
    plt.grid(True)
    ax.set_ylabel(r"$\tau_4 \ [-]$", fontsize = 14)
    ax.set_xlim(0, max(t_list))
    ax.set_xlabel(r'\textbf{Time (s)}')
    # ax.legend((r"$q_0$",r"$q_{0d}$"),loc="upper right")
    fig.tight_layout()

    ax = plt.subplot(3, 2, 6)
    plt.plot(t, tau[:, 5])
    plt.grid(True)
    ax.set_ylabel(r"$\tau_5 \ [-]$", fontsize = 14)
    ax.set_xlim(0, max(t_list))
    ax.set_xlabel(r'\textbf{Time (s)}')
    # ax.legend((r"$q_0$",r"$q_{0d}$"),loc="upper right")
    fig.tight_layout()

    plt.show()

def graphs_pose(t, pose, pose_des):
    fig, ax = plt.subplots()
    ax = plt.subplot(3, 1, 1)
    plt.plot(t, pose[:, 0])
    plt.plot(t, pose_des[:, 0],linestyle='--')
    plt.grid(True)
    ax.set_ylabel(r"$x \ [m]$", fontsize = 14)
    ax.set_xlim(0, max(t))
    # ax.set_ylim(-0.95, 0.95)
    ax.set_xlabel(r'\textbf{Time (s)}')
    ax.legend((r"$x$",r"$x_{d}$"),loc="upper right")
    fig.tight_layout()

    ax = plt.subplot(3, 1, 2)
    plt.plot(t, pose[:, 1])
    plt.plot(t, pose_des[:, 1],linestyle='--')
    plt.grid(True)
    ax.set_ylabel(r"$y \ [m]$", fontsize = 14)
    ax.set_xlim(0, max(t))
    # ax.set_ylim(-0.95, 0.95)
    ax.set_xlabel(r'\textbf{Time (s)}')
    ax.legend((r"$y$",r"$y_{d}$"),loc="upper right")
    fig.tight_layout()

    ax = plt.subplot(3, 1, 3)
    plt.plot(t, pose[:, 2])
    plt.plot(t, pose_des[:, 2],linestyle='--')
    plt.grid(True)
    ax.set_ylabel(r"$z \ [m]$", fontsize = 14)
    # ax.set_ylim(-0.95, 0.95)
    ax.set_xlim(0, max(t))
    ax.set_xlabel(r'\textbf{Time (s)}')
    ax.legend((r"$z$",r"$z_{d}$"),loc="upper right")
    fig.tight_layout()
    plt.show()

# %%
graphs_qs(t_list, q_list)

# %%
graphs_taus(t_list, u_list)

# %%
graphs_pose(t_list, pose_list, pose_des_list)
